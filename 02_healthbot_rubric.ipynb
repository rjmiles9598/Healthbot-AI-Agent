# %% [markdown]
# # **Model and Tools LangGraph Configuration:**
#
# ### __Criteria__
# - Properly configure OpenAI and Tavily so that the model is capable of calling Tavily Search
#
# #### __Submission Requirements__
# - API Keys are loaded correctly
#
# - Sucessful API calls are made to both Tavily and OpenAI services
# - OpenAI successfully calls Tavily for search.
#
#
# ## ABOVE IS COMPLETED

# %% [markdown]
# # **Model Summarization of Search Results:**
#
# ### __Criteria__
# - Correctly configure the model to summarize the search results from Tavily.
#
# #### __Submission Requirements__
# - The model has called Tavily for the desired learning subject
# - The model has received the Tavily search results
#
# - The model has been given a well written prompt to summarize the search results, using no other knowledge or data sources.
# - The model has created a 3-4 paragraph summarization of the search results

# %% [markdown]
# # **Model Quiz Question Creation and Grading using Summarization**
#
# ### __Criteria__
# - Correctly configure the model to create a quiz using only the data from the summarization
#
# - Correctly configure the model to grade the users answer to the quiz question
#
# #### __Submission Requirements__
# - The model has been given a well written prompt to create a quiz question using only the data from the summarizaion
# - The quiz question should be answerable using the summary alone.
#
# - The model should grade the users answer to the quiz question, sing only the summary as a data source
# - The model should provide a grade (A, B, C, etc) as well as justification why itgave the grade that it did.

# %% [markdown]
# # **LangGraph State:**
#
# ### __Criteria__
#
# - Correctly configre nodes and edges that allow for a learning workflow with human interaction to be executed
#
# #### __Submission Requirement__
# - Multiple nodes exist for the necessary steps in the workflow, such as search, user input, etc.
#
#      - nodes appropriately reference and update state
#
#      - Ideally nodes will have a single responsibility, such as collect user input, display output, etc.
#
# - Edges are configured in a way that bring the user though the sequential workflow nodes
#
#      - The user should be able to restart the workflow or exit after the grade as been presented.
#
# - The entire workflow is executed and functions per the requirements
#
#      - The user is able to enter a subject, see the summary, take a quiz, see the quiz grade, and opt to learn about a new subject or exit.
